# %%
import pandas as pd
import getpass
import sqlalchemy as sa

# %%
driver = 'mysql+pymysql'
user = 'root'
password = getpass.getpass(prompt='Your password:'"")
ip = '127.0.0.1'
# Out:
# Your password:········

# %%
connection_string = f'{driver}://{user}:{password}@{ip}'

# %%
db_connection = sa.create_engine(connection_string)

# %%
result = db_connection.execute('SELECT * FROM lab_db.data_marketing_cs')
result
for row in result:
    print(row)
# Out:
# ('Arizona', 4809, 'No', 'Basic', 'College', '2/18/11', 'Employed', 'M', 48029, 'Suburban', 'Married', 61, '7.0', 52, 0, 9, 'Corporate Auto', 'Corporate L3', 'Offer3', 'Agent', 292.8, 'Four-Door Car', 'Medsize', 'nan')
# ('California', 2229, 'No', 'Basic', 'College', '1/18/11', 'Unemployed', 'F', 0, 'Suburban', 'Single', 64, '3.0', 26, 0, 1, 'Personal Auto', 'Personal L3', 'Offer4', 'Call Center', 744.924331, 'Four-Door Car', 'Medsize', 'nan')
# ('Washington', 14948, 'No', 'Basic', 'Bachelor', '2/10/11', 'Employed', 'M', 22139, 'Suburban', 'Single', 100, '34.0', 31, 0, 2, 'Personal Auto', 'Personal L3', 'Offer3', 'Call Center', 480.0, 'SUV', 'Medsize', 'A')
# ('Oregon', 22332, 'Yes', 'Extended', 'College', '1/11/11', 'Employed', 'M', 49078, 'Suburban', 'Single', 97, '10.0', 3, 0, 2, 'Corporate Auto', 'Corporate L3', 'Offer2', 'Branch', 484.013411, 'Four-Door Car', 'Medsize', 'A')
# ...

# %%
query="Select * FROM lab_db.data_marketing_cs"
data_marketing_cs= pd.read_sql_query(query, db_connection)

# %%
data_marketing_cs.head()
# Out:
#         state  customer_lifetime_value response  coverage education  \
# 0     Arizona                     4809       No     Basic   College
# 1  California                     2229       No     Basic   College
# 2  Washington                    14948       No     Basic  Bachelor
# 3      Oregon                    22332      Yes  Extended   College
# 4      Oregon                     9025       No   Premium  Bachelor
#
#   effective_to_date employment_status gender  income location_code  ...  \
# 0           2/18/11          Employed      M   48029      Suburban  ...
# 1           1/18/11        Unemployed      F       0      Suburban  ...
# 2           2/10/11          Employed      M   22139      Suburban  ...
# 3           1/11/11          Employed      M   49078      Suburban  ...
# 4           1/17/11     Medical Leave      F   23675      Suburban  ...
#
#   nr_open_complaints  number_of_policies     policy_type        policy  \
# ...
