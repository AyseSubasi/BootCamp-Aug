# %% [markdown]
# # Holiday preference

# %%
def name():
    her_name=input(" Enter your name: ")
    print(" Hello " + str(her_name))
    return

name()
# Out:
#  Enter your name: Alice
#  Hello Alice

# %% [markdown]
# ### Image of Alice
#
# ![alice-pic.png](attachment:alice-pic.png)

# %%
def preference():
    her_pref=input("Choose your preferred  option \n a. Beach \n b. Mountains \n c. City\n Answer:")
    print("Your preference: " + str(her_pref))
    return

preference()
# Out:
# Choose your preferred  option
#  a. Beach
#  b. Mountains
#  c. City
#  Answer:Beach
# Your preference: Beach

# %% [markdown]
# ### Holiday destination
#
# ![beach.png](attachment:beach.png)

# %% [markdown]
# ### Top 3
#
# <span style="color:darkblue"> - **snorkeling**
#
# <span style="color:darkblue">- **sunbathing**
#
# <span style="color:darkblue">- **swimming**

# %% [markdown]
# Video of destination: [Bali](https://www.youtube.com/watch?v=LCqK7wZd2Pk)!
