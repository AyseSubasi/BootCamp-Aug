# %%
import pandas as pd

# %%
ls
# Out:
# Health Care Case Study.ipynb
# Health_Care_for_All_Case_Study.md
# Healthcare Case Study - Ayse.ipynb
# Notebook_Code_Along_Intro_To_Pandas_Healthcare_For_All.ipynb
# helathcareforall.csv

# %%
health4all = pd.read_csv("./helathcareforall.csv")

# %%
health4all
# Out:
#       CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2        43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F   995.00  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 1002    114721    OK    NaN     1040  472  656.0     0  26962      2     56
# 1003    149152    CA      M     4507  842  962.0    95  54642     17     50
# 1004       959    IA      F      586  349  465.0     1  15304      1     77
# 1005    179563    WA   male      842  420  494.0     2  12894     41     24
# 1006     41243    FL      F      556  246  330.0     0  10272      2     56
#
# ...

# %%
#lower
health4all=health4all.rename(columns=str.lower)

health4all
# Out:
#       controln state gender      hv1  ic1    ic4  hvp1    ic5  pobc1  pobc2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2        43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F   995.00  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 1002    114721    OK    NaN     1040  472  656.0     0  26962      2     56
# 1003    149152    CA      M     4507  842  962.0    95  54642     17     50
# 1004       959    IA      F      586  349  465.0     1  15304      1     77
# 1005    179563    WA   male      842  420  494.0     2  12894     41     24
# 1006     41243    FL      F      556  246  330.0     0  10272      2     56
#
# ...

# %%
#rename column

health4all.rename(columns={"hv1":"med_home_value_hun","ic1":"med_houshold_inc_hun","ic2":"med_family_income","ic3":"med_fam_income","ic4":"avg_household_income","hvp1":"per_hom_value", "ic5": "per_capita_income", "pobc1": "per_foreign_born", "pobc2": "per_born_state_res"}, inplace=True )

# %%
health4all.head(10)
# Out:
#    controln state  gender med_home_value_hun  med_houshold_inc_hun  \
# 0     44060    FL       M             AAA896                   392
# 1     96093    IL       M             537.00                   365
# 2     43333    FL       F             725.00                   301
# 3     21885    NC       M            AAA1095                   401
# 4    190108    FL       F             995.00                   252
# 5    100640    IL       M             764.00                   457
# 6     18581    NC  female             775.00                   318
# 7    119038    TX       M             890.00                   519
# 8    173223    CA       F                NaN                   184
# 9    157988    CA       F            AAA2294                   593
#
#    avg_household_income  per_hom_value per_capita_income  per_foreign_born  \
# 0                 520.0              7             21975                 6
# 1                 473.0              0             19387                 1
# ...

# %%
#state typo

health4all.state.unique()
# Out:
# array(['FL', 'IL', 'NC', 'TX', 'CA', 'NV', 'Cali', 'AP', 'KS', 'MI', 'OK',
#        'AR', 'IN', 'MT', 'WI', 'MO', 'HI', 'UT', 'GA', 'WA', 'ID', 'CT',
#        'AL', 'ND', 'SC', 'IA', 'CO', 'LA', 'OR', 'SD', 'TN', 'NM', 'AZ',
#        'MN', 'KY', 'NJ', 'NE', 'California', 'MS', 'NY', 'Arizona', 'WY',
#        'Tennessee'], dtype=object)

# %%
# Out:
#   File "<ipython-input-22-636940c92921>", line 1
#     health4all.state(map("California": "CA", "Cali": "CA", "Arizona":"AZ", "Tennesse": "TN"))
#                                      ^
# SyntaxError: invalid syntax
